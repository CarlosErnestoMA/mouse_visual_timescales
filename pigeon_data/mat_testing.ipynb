# %%
import h5py
data = h5py.File('test.mat' , 'r')
data
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 2
#       1 import h5py
# ----> 2 data = h5py.File('test.mat' , 'r')
#       3 data
#
# File ~/miniforge3/envs/mat_playground/lib/python3.10/site-packages/h5py/_hl/files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     552     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     553                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     554                      alignment_threshold=alignment_threshold,
#     555                      alignment_interval=alignment_interval,
# ...

# %%
import mat4py

filename = 'SPP2205.mat'

# %%
data = mat4py.loadmat(filename)
data
# Out:
# ---------------------------------------------------------------------------
# ParseError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = mat4py.loadmat(filename)
#       2 data
#
# File ~/miniforge3/envs/mat_playground/lib/python3.10/site-packages/mat4py/loadmat.py:467, in loadmat(filename, meta)
#     463     raise ParseError('Duplicate variable name "{}" in mat file.'
#     464                      .format(name))
#     466 # read the matrix
# --> 467 mdict[name] = read_var_array(fd_var, endian, hdr)
#     468 if meta and hdr['is_global']:
#     469     mdict['__globals__'].append(name)
#
# File ~/miniforge3/envs/mat_playground/lib/python3.10/site-packages/mat4py/loadmat.py:374, in read_var_array(fd, endian, header)
#     372     return read_cell_array(fd, endian, header)
#     373 elif mc == 'mxSTRUCT_CLASS':
# --> 374     return read_struct_array(fd, endian, header)
#     375 elif mc == 'mxOBJECT_CLASS':
# ...

# %%
import pymatreader

data= pymatreader.read_mat(filename)
# Out:
# /home/marcelraabe/miniforge3/envs/mat_playground/lib/python3.10/site-packages/pymatreader/utils.py:283: UserWarning: pymatreader cannot import Matlab string variables. Please convert these variables to char arrays in Matlab.
#   warn(

# %%
data["data"]["region"]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
import pandas as pd

df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
# ----> 3 df = pd.DataFrame(data)
#
# File ~/miniforge3/envs/mat_playground/lib/python3.10/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...
